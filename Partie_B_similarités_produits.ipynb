# %% [markdown]
# Lien github du projet : [Github](https://github.com/QuentinNav/Clustering-de-produits-alimentaires "Clustering de produits alimentaires")

# %% [markdown]
# # Partie B : Comparaison des produits

# %% [markdown]
# Les produits sont composés de 1 ou plusieurs vecteurs, nous souhaitons calculer leur niveau de similarité. \
# Il faut donc trouver une solution pour comparer des produits avec des dimensions différentes.

# %% [markdown]
# Pour comparer deux produits entre eux nous utilisons la similarité cosinus.

# %% [markdown]
# L'idée globale est de déterminer une fonction pour comparer tous les produits entre eux 2 à 2, comme nous avons pour l'instant gardé 700 000  produits dans le dataset, la vitesse d'exécution du code est un enjeu important.\
# Il se peut que l'on soit dans l'obligation de réduire la taille du dataset afin d'obtenir un temps d'exécution acceptable.

# %% [markdown]
# ## Import et installation des librairies et fonctions

# %%
#Import du drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from compute_similarities import *
from config import data_path

# %% [markdown]
# ## Chargement des données

# %%
df_ingredients_word2vec = pd.read_csv(data_path+"ingredients_word2vec.csv", sep="\t").set_index("ingredient")

df= pd.read_csv(data_path+"cleaned_data.csv", sep="\t", low_memory=False)
df['liste_ingredients'] = df['liste_ingredients'].str.strip('[]').str.replace(" ","").str.replace("'","").str.split(',')
df["product_name"]= df["product_name"].astype(str)

df.head()
# Out:
#              product_name                                   ingredients_tags  \
# 0                 L.casei  {'en': ['semi-skimmed-milk', 'dairy', 'milk', ...
# 1  Solène céréales poulet  {'en': ['antioxidant', 'colour', 'tomato', 've...
# 2  Crème dessert chocolat  {'en': ['whole-milk', 'dairy', 'milk', 'sugar'...
# 3       Baguette Poitevin  {'en': [None, 'water', 'salt', 'yeast', 'glute...
# 4          Suedois saumon  {'en': [None, 'water', 'rye-flour', 'flour', '...
#
#                                    liste_ingredients  \
# 0  [semi-skimmed-milk, dairy, milk, sugar, added-...
# 1  [antioxidant, colour, tomato, vegetable, mayon...
# 2  [whole-milk, dairy, milk, sugar, added-sugar, ...
# 3  [water, salt, yeast, gluten, e300, wheat-flour...
# 4  [water, rye-flour, flour, cereal-flour, sugar,...
#
#    nombre_ingredients_pre_filtre  nombre_ingredients  \
# 0                             14                  12
# 1                             32                  32
# 2                             10                  10
# 3                             23                  14
# 4                             42                  36
#
#    nombre_ingredients_perdus  part_ingredients_perdus
# 0                          2                 0.142857
# 1                          0                 0.000000
# 2                          0                 0.000000
# 3                          9                 0.391304
# 4                          6                 0.142857

# %% [markdown]
# ## Matrice des similarités

# %% [markdown]
# Pour accélérer les algorithmes de comparaison des produits nous calculons à l'avance la matrice des similarités cosinus entre tous les produits.

# %% [markdown]
# Dimensions : 812 x 812

# %%
df_similarities = compute_similarity_matrix(df_ingredients_word2vec)
df_similarities.head()
# Out:
#                    semi-skimmed-milk     dairy      milk     sugar  \
# semi-skimmed-milk           1.000000  0.812481  0.856659  0.408533
# dairy                       0.812481  1.000000  0.922171  0.631504
# milk                        0.856659  0.922171  1.000000  0.466385
# sugar                       0.408533  0.631504  0.466385  1.000000
# added-sugar                 0.374410  0.590832  0.417522  0.989781
#
#                    added-sugar  disaccharide  lactic-ferments   ferment  \
# semi-skimmed-milk     0.374410      0.395696         0.825005  0.791201
# dairy                 0.590832      0.624127         0.630645  0.598705
# milk                  0.417522      0.456121         0.755143  0.738621
# sugar                 0.989781      0.998432         0.284654  0.287253
# added-sugar           1.000000      0.989594         0.253843  0.269749
#
#                    microbial-culture  vitamins  ...  wholemeal-oat-flour  \
# semi-skimmed-milk           0.761323  0.399250  ...             0.200331
# dairy                       0.574923  0.252504  ...             0.278563
# milk                        0.719190  0.341347  ...             0.108866
# sugar                       0.249729  0.139359  ...             0.467385
# added-sugar                 0.223360  0.150211  ...             0.480627
#
#                    lactobacillus-bulgaricus  lactobacillus  \
# semi-skimmed-milk                  0.664569       0.590097
# dairy                              0.415509       0.419602
# milk                               0.578011       0.571979
# sugar                              0.209229       0.249344
# added-sugar                        0.183850       0.239396
#
#                    streptococcus-thermophilus  lactobacillus-acidophilus  \
# semi-skimmed-milk                    0.636515                   0.615569
# dairy                                0.405257                   0.446888
# milk                                 0.581873                   0.591607
# sugar                                0.210427                   0.246889
# added-sugar                          0.188048                   0.238880
#
#                     bifidus  zinc-sulfate  pork-collagen  \
# semi-skimmed-milk  0.612478      0.287747       0.391179
# dairy              0.429913      0.049415       0.252374
# milk               0.563413      0.180897       0.375677
# sugar              0.229958     -0.099358       0.338123
# added-sugar        0.217283     -0.115915       0.379745
#
#                    spice-or-bell-pepper  superior-quality-durum-wheat-semolina
# semi-skimmed-milk              0.101340                               0.359987
# dairy                          0.173808                               0.308890
# milk                           0.129618                               0.254378
# sugar                          0.543702                               0.444924
# added-sugar                    0.539926                               0.396437
#
# [5 rows x 812 columns]

# %% [markdown]
# ## Fonctions pour calculer les similarités entre les produits

# %% [markdown]
# ### Essais des fonctions de comparaison de produits par Max pooling et average pooling

# %% [markdown]
# * A est le produit pour lequel on cherche des produits similaires
# * B est un autre produit du dataframe que l'on compare à A

# %% [markdown]
# #### Max pooling

# %%
df_test = find_similar_products_max_pooling(df,"Crème dessert chocolat")
df_test.sort_values("similarity",ascending=False).head(15)
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
#                                              product_name  \
# 200535                                       Profiteroles
# 617940                Génoise au cacao fourrée au praliné
# 621829                                      Tourte nougat
# 268399                                   Gourmet cupcakes
# 629896                                          La recova
# 992                                       Chocolate Bites
# 621850                                   Tourte au Nougat
# 44411                                     Frosted Cookies
# 468910                               6 Macarons gourmands
# 24056           Lunds & byerlys, shortcake, lemon & cream
# 24028                           Lunds & byerlys, yule log
# 46309   Moist Chocolate Cupcakes Fillet With Creamy Fu...
# 654445                                       profiteroles
# 629897                                      Junior Blanco
# 629880                        Alfajor de chocolate blanco
#
#                                         liste_ingredients  similarity
# 200535  [dairy, cream, sugar, added-sugar, disaccharid...    1.000000
# 617940  [sugar, added-sugar, disaccharide, whole-milk,...    1.000000
# 621829  [sugar, added-sugar, disaccharide, whole-milk,...    1.000000
# 268399  [icing-sugar, added-sugar, disaccharide, sugar...    1.000000
# 629896  [dairy, milk, condensed-milk, sweetened-conden...    1.000000
# 992     [sugar, added-sugar, disaccharide, wheat-flour...    1.000000
# 621850  [whole-milk, dairy, milk, sugar, added-sugar, ...    1.000000
# 44411   [flour, vegetable-fat, oil-and-fat, vegetable-...    1.000000
# 468910  [sugar, added-sugar, disaccharide, nut, tree-n...    1.000000
# 24056   [lemon, fruit, citrus-fruit, sugar, added-suga...    1.000000
# 24028   [sugar, added-sugar, disaccharide, dark-chocol...    1.000000
# 46309   [sugar, added-sugar, disaccharide, icing-sugar...    1.000000
# 654445  [chocolate, skimmed-milk, dairy, milk, sugar, ...    0.998821
# 629897  [dairy, milk, condensed-milk, sweetened-conden...    0.998821
# 629880  [dairy, milk, condensed-milk, sweetened-conden...    0.998821

# %% [markdown]
# Nous observons que les produits avec beaucoup d'ingrédients sont énormément avantagés.\
# En effet comme nous récupérons la similarité maximale trouvée pour chaque ingrédients de A avec chaque ingrédient de B, si un produit contient beaucoup d'ingrédients il a plus de chance d'avoir un ingrédient similaire pour chaque ingrédient de B.\
# L'inconvénient est qu'il peut aussi avoir beaucoup d'ingrédients en plus qui n'ont pas de rapport avec A et il ne sera pas pénalisé.

# %% [markdown]
# Pour que B obtienne un bon score avec cette méthode il faut que les ingrédients de A soient inclus dans les ingrédients de B.

# %% [markdown]
# #### Average Pooling

# %%
df_test2 = find_similar_products_avg_pooling(df,"Crème dessert chocolat")
df_test2.sort_values("similarity",ascending=False).head(15)
# Out:
# 100%|██████████| 10/10 [01:41<00:00, 10.12s/it]
#                                      product_name liste_ingredients  \
# 409253                     Creme fraiche d'Isigny    [dairy, cream]
# 612056         Freefrom Crème fraîche Lactosefrei    [cream, dairy]
# 117526              Farmer s sweet whipped butter    [cream, dairy]
# 167766                                 Sour Cream    [cream, dairy]
# 167764                                 Sour Cream    [cream, dairy]
# 167763                                 Sour Cream    [cream, dairy]
# 589571                             Masło osełkowe    [cream, dairy]
# 589570                                Masło extra    [cream, dairy]
# 27900                         Organic half & half    [cream, dairy]
# 534702                              Crème fraîche    [cream, dairy]
# 428346       Crème fraîche de Normandie (42 % MG)    [dairy, cream]
# 589495          twarożek &quot;Mój ulubiony&quot;    [cream, dairy]
# 589494                               Mój Ulubiony    [cream, dairy]
# 589407  Masło ekstra z Kujaw i ziemi dobrzyńskiej    [cream, dairy]
# 685004                               Fassl Butter    [cream, dairy]
#
#         similarity
# 409253    0.642045
# 612056    0.642045
# 117526    0.642045
# 167766    0.642045
# 167764    0.642045
# 167763    0.642045
# 589571    0.642045
# 589570    0.642045
# 27900     0.642045
# 534702    0.642045
# 428346    0.642045
# 589495    0.642045
# 589494    0.642045
# 589407    0.642045
# 685004    0.642045

# %% [markdown]
# Au contraire, ici les produits avec peu d'ingrédients semblent être avantagés.\
# Comme nous gardons la moyenne des similarités entre les chaque ingrédient de A et tous les ingrédients de B, si les ingrédients de A sont "distants" même si B les contient, le score de similarité sera pénalisé.

# %% [markdown]
# Pour avoir un bon score de similarité avec cette technique il faut que les ingrédients de B soient inclus dans ceux de A.

# %% [markdown]
# ## Solution

# %% [markdown]
# Pour remédier à ce problème nous repartons de la fonction des similarités effectuant un max pooling mais cette fois nous l'effectuons dans les 2 sens.

# %% [markdown]
# Si l'on test cette méthode sur le produit qui a eu le meilleur score de similarité avec le max pooling, nous remarquons que le deuxième score est beaucoup moins bon et donc que cette méthode ne l'aurai pas mais aussi haut dans le classement des produits similaires.

# %%
A =df.iloc[2]["liste_ingredients"]#Liste des ingrédients de la Crème chocolat
B = df.loc[df["product_name"]=="Chocolate Bites","liste_ingredients"].iloc[0]# Liste des ingrédients des "Chocolate bites"

# %%
print('Similarité Max pooling des ingrédients de A dans B : ',similarity_max_A_dans_B(A,B))
print('Similarité Max pooling des ingrédients de B dans A : ',similarity_max_A_dans_B(B,A))
# Out:
# Similarité Max pooling des ingrédients de A dans B :  1.0
# Similarité Max pooling des ingrédients de B dans A :  0.6262173263633892

# %%
dicts_A = [df_similarities[ingredient].to_dict() for ingredient in A] 
print(A)
print(B)
similarities_both_ways(A,B,dicts_A)
# Out:
# ['whole-milk', 'dairy', 'milk', 'sugar', 'added-sugar', 'disaccharide', 'corn-starch', 'starch', 'cocoa', 'e406']
# ['sugar', 'added-sugar', 'disaccharide', 'wheat-flour', 'cereal', 'flour', 'wheat', 'cereal-flour', 'palm-kernel-oil', 'oil-and-fat', 'vegetable-oil-and-fat', 'palm-kernel-oil-and-fat', 'whey', 'dairy', 'water', 'egg-yolk', 'egg', 'soya-oil', 'vegetable-oil', 'soya-flour', 'legume', 'soya', 'soya-bean', 'sour-cream', 'cream', 'cocoa-powder', 'cocoa', 'skimmed-milk', 'milk', 'corn-syrup', 'raising-agent', 'corn-starch', 'starch', 'wheat-starch', 'salt', 'e170i', 'e170', 'soya-lecithin', 'e322', 'e322i', 'dextrose', 'monosaccharide', 'glucose', 'e471', 'spice', 'condiment', 'e406', 'e490', 'e491', 'e466', 'natural-and-artificial-flavouring', 'flavouring', 'natural-flavouring', 'artificial-flavouring', 'corn-oil', 'e330', 'barley-malt-flour', 'barley', 'barley-flour', 'e375', 'reduced-iron', 'minerals', 'iron', 'thiamin-mononitrate', 'thiamin', 'e101', 'folic-acid', 'folate', 'cottonseed-oil', 'skimmed-milk-powder', 'milk-powder', 'whole-milk', 'e270', 'e450i', 'e450', 'e500ii', 'e500', 'e341i', 'e341']
# (1.0, 0.6262173263633892)

# %% [markdown]
# Le deuxième score est nettement moins bon.

# %% [markdown]
# ### On reprend le même exemple avec la nouvelle méthode

# %%
# %%time
df_test = find_similar_products_max_pooling_both_ways(df, "Crème dessert chocolat")
df_test.head(10)
# Out:
# 100%|██████████| 701084/701084 [36:06<00:00, 323.64it/s]
# CPU times: user 34min 9s, sys: 49.1 s, total: 34min 58s
# Wall time: 36min 7s
#                                      product_name  \
# 502997                   Creme dessert artisanale
# 355916                              Crème dessert
# 536327      Délices de lait - Crème dessert Cacao
# 440923                  Crème dessert au chocolat
# 528512  Landliebe Sahne Pudding Dunkle Schokolade
# 677269                Ovocný košík s kousky jahod
# 447631                    Lactel max bio chocolat
# 500772                    Crèmes dessert chocolat
# 425199                 P'tit Goûter au lait cacao
# 424994              P'tit Gouter Au Lait chocolat
#
#                                         liste_ingredients  similarity1  \
# 502997  [dairy, milk, whole-milk, sugar, added-sugar, ...     0.975463
# 355916  [dairy, milk, pasteurised-milk, whole-milk, ca...     0.978254
# 536327  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.980800
# 440923  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.975463
# 528512  [whole-milk, dairy, milk, modified-starch, sta...     0.945702
# 677269  [milk, dairy, milk-powder, sugar, added-sugar,...     0.962020
# 447631  [semi-skimmed-milk, dairy, milk, rice-starch, ...     0.969071
# 500772  [dairy, milk, pasteurised-milk, whole-milk, su...     0.945702
# 425199  [whole-milk, dairy, milk, cane-sugar, added-su...     0.951536
# 424994  [whole-milk, dairy, milk, cane-sugar, added-su...     0.951536
#
#         similarity2  mean_similarity
# 502997     0.966879         0.971171
# 355916     0.958944         0.968599
# 536327     0.952819         0.966810
# 440923     0.957325         0.966394
# 528512     0.984950         0.965326
# 677269     0.966869         0.964444
# 447631     0.959748         0.964410
# 500772     0.976264         0.960983
# 425199     0.966104         0.958820
# 424994     0.966104         0.958820

# %% [markdown]
# Le temps d'exécution est très long.

# %% [markdown]
# ### Optimisation de la fonction

# %% [markdown]
# #### V2

# %%
# %%time
df_test = find_similar_products_max_pooling_both_waysV2(df, "Crème dessert chocolat")
df_test.head(10)
# Out:
# CPU times: user 2min 2s, sys: 2.41 s, total: 2min 5s
# Wall time: 2min 7s
#                                      product_name  \
# 497444                   Creme dessert artisanale
# 352550                              Crème dessert
# 436326                  Crème dessert au chocolat
# 530200      Délices de lait - Crème dessert Cacao
# 442920                    Lactel max bio chocolat
# 522517  Landliebe Sahne Pudding Dunkle Schokolade
# 668393                Ovocný košík s kousky jahod
# 495263                    Crèmes dessert chocolat
# 535656                             Schoko Pudding
# 420849                 P'tit Goûter au lait cacao
#
#                                         liste_ingredients  similarity1  \
# 497444  [dairy, milk, whole-milk, sugar, added-sugar, ...     0.978151
# 352550  [dairy, milk, pasteurised-milk, whole-milk, ca...     0.980159
# 436326  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.978151
# 530200  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.983300
# 442920  [semi-skimmed-milk, dairy, milk, rice-starch, ...     0.972582
# 522517  [whole-milk, dairy, milk, modified-starch, sta...     0.945112
# 668393  [milk, dairy, milk-powder, sugar, added-sugar,...     0.961873
# 495263  [dairy, milk, pasteurised-milk, whole-milk, su...     0.945112
# 535656  [whole-milk, dairy, milk, added-sugar, disacch...     0.957248
# 420849  [whole-milk, dairy, milk, cane-sugar, added-su...     0.953359
#
#         similarity2  mean_similarity
# 497444     0.968251         0.973201
# 352550     0.960495         0.970327
# 436326     0.960278         0.969215
# 530200     0.953759         0.968530
# 442920     0.963024         0.967803
# 522517     0.985059         0.965086
# 668393     0.965706         0.963790
# 495263     0.975642         0.960377
# 535656     0.962144         0.959696
# 420849     0.965138         0.959248

# %% [markdown]
# ### V3

# %%
# %%time
df_test =find_similar_products_max_pooling_both_waysV3(df, "Crème dessert chocolat")
df_test.head(10)
# Out:
# CPU times: user 1min 36s, sys: 976 ms, total: 1min 37s
# Wall time: 1min 37s
#                                      product_name  \
# 497444                   Creme dessert artisanale
# 352550                              Crème dessert
# 436326                  Crème dessert au chocolat
# 530200      Délices de lait - Crème dessert Cacao
# 442920                    Lactel max bio chocolat
# 522517  Landliebe Sahne Pudding Dunkle Schokolade
# 668393                Ovocný košík s kousky jahod
# 495263                    Crèmes dessert chocolat
# 535656                             Schoko Pudding
# 420849                 P'tit Goûter au lait cacao
#
#                                         liste_ingredients  similarity1  \
# 497444  [dairy, milk, whole-milk, sugar, added-sugar, ...     0.978151
# 352550  [dairy, milk, pasteurised-milk, whole-milk, ca...     0.980159
# 436326  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.978151
# 530200  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.983300
# 442920  [semi-skimmed-milk, dairy, milk, rice-starch, ...     0.972582
# 522517  [whole-milk, dairy, milk, modified-starch, sta...     0.945112
# 668393  [milk, dairy, milk-powder, sugar, added-sugar,...     0.961873
# 495263  [dairy, milk, pasteurised-milk, whole-milk, su...     0.945112
# 535656  [whole-milk, dairy, milk, added-sugar, disacch...     0.957248
# 420849  [whole-milk, dairy, milk, cane-sugar, added-su...     0.953359
#
#         similarity2  mean_similarity
# 497444     0.968251         0.973201
# 352550     0.960495         0.970327
# 436326     0.960278         0.969215
# 530200     0.953759         0.968530
# 442920     0.963024         0.967803
# 522517     0.985059         0.965086
# 668393     0.965706         0.963790
# 495263     0.975642         0.960377
# 535656     0.962144         0.959696
# 420849     0.965138         0.959248

# %% [markdown]
# ### V3 avec multiprocessing

# %%
mp.cpu_count()
# Out:
# 2

# %% [markdown]
# Comme il n'y a que 2 cpu sur google colab la différence n'est pas si grande mais on gagne tout de même une trentaine de secondes.

# %%
# %%time
df_test =find_similar_products_max_pooling_both_waysV3_multiprocessing(df, "Crème dessert chocolat")
df_test.head(10)
# Out:
# CPU times: user 15.1 s, sys: 2.88 s, total: 18 s
# Wall time: 1min 14s
#                                      product_name  \
# 497444                   Creme dessert artisanale
# 352550                              Crème dessert
# 436326                  Crème dessert au chocolat
# 530200      Délices de lait - Crème dessert Cacao
# 442920                    Lactel max bio chocolat
# 522517  Landliebe Sahne Pudding Dunkle Schokolade
# 668393                Ovocný košík s kousky jahod
# 495263                    Crèmes dessert chocolat
# 535656                             Schoko Pudding
# 420849                 P'tit Goûter au lait cacao
#
#                                         liste_ingredients  similarity1  \
# 497444  [dairy, milk, whole-milk, sugar, added-sugar, ...     0.978151
# 352550  [dairy, milk, pasteurised-milk, whole-milk, ca...     0.980159
# 436326  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.978151
# 530200  [whole-milk, dairy, milk, sugar, added-sugar, ...     0.983300
# 442920  [semi-skimmed-milk, dairy, milk, rice-starch, ...     0.972582
# 522517  [whole-milk, dairy, milk, modified-starch, sta...     0.945112
# 668393  [milk, dairy, milk-powder, sugar, added-sugar,...     0.961873
# 495263  [dairy, milk, pasteurised-milk, whole-milk, su...     0.945112
# 535656  [whole-milk, dairy, milk, added-sugar, disacch...     0.957248
# 420849  [whole-milk, dairy, milk, cane-sugar, added-su...     0.953359
#
#         similarity2  mean_similarity
# 497444     0.968251         0.973201
# 352550     0.960495         0.970327
# 436326     0.960278         0.969215
# 530200     0.953759         0.968530
# 442920     0.963024         0.967803
# 522517     0.985059         0.965086
# 668393     0.965706         0.963790
# 495263     0.975642         0.960377
# 535656     0.962144         0.959696
# 420849     0.965138         0.959248

# %% [markdown]
# ## Comparaison des 3 méthodes sur un plus petit échantillon du dataframe :

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]

# %%
def find_similar_products_max_pooling_both_waysV3_multiprocessing(df_products, product_name):
    liste_ingredients = df_products.loc[df_products["product_name"]==product_name, "liste_ingredients"].iloc[0]

    df_temp = df_products[df_products["product_name"]!=product_name]# On retire le produits testé de la liste
    list_dicts = [df_similarities[ingredient].to_dict() for ingredient in liste_ingredients]

    with mp.Pool(mp.cpu_count()) as pool :
        df_temp[["similarity1","similarity2"]] = pool.starmap(similarities_both_ways, zip(repeat(liste_ingredients),df_temp["liste_ingredients"], repeat(list_dicts)))

    df_temp["mean_similarity"] = (df_temp["similarity1"] + df_temp["similarity2"])/2


    return df_temp[["product_name","liste_ingredients","similarity1","similarity2","mean_similarity"]].sort_values("mean_similarity",ascending=False)

# %%
# %%time 
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV2(df_temp, product_name)
df_test.head(10)
# Out:
# Produits similaires au produit : Apple juice cocktail from concentrate
# CPU times: user 22.5 s, sys: 330 ms, total: 22.8 s
# Wall time: 23 s
#                                              product_name  \
# 73879                Clover valley, juice cocktail, apple
# 308674                       Bogopa, Apple Juice Cocktail
# 205647                 Apple Juice Drink From Concentrate
# 210870  Apple juice cocktail flavored with other natur...
# 162362                            Dreamworks, Fruit Punch
# 153943             Mr. Pure, Juice Drink, Apple Cranberry
# 250398  Cranberry apple flavored juice cocktail from c...
# 2868                       Cranberry Apple Juice Cocktail
# 320108                           Goliath, Nectar Tropical
# 52471   Cranberry apple juice cocktail from concentrat...
#
#                                         liste_ingredients  similarity1  \
# 73879   [filtered-water, water, high-fructose-corn-syr...     0.964740
# 308674  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 205647  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 210870  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 162362  [filtered-water, water, high-fructose-corn-syr...     0.987817
# 153943  [water, high-fructose-corn-syrup, added-sugar,...     0.963618
# 250398  [filtered-water, water, high-fructose-corn-syr...     0.949193
# 2868    [filtered-water, water, high-fructose-corn-syr...     0.949193
# 320108  [water, high-fructose-corn-syrup, added-sugar,...     0.968173
# 52471   [filtered-water, water, high-fructose-corn-syr...     0.965086
#
#         similarity2  mean_similarity
# 73879      1.000000         0.982370
# 308674     1.000000         0.976196
# 205647     1.000000         0.976196
# 210870     0.996696         0.974544
# 162362     0.952982         0.970400
# 153943     0.969001         0.966309
# 250398     0.980084         0.964639
# 2868       0.978741         0.963967
# 320108     0.956363         0.962268
# 52471      0.947506         0.956296

# %%
# %%time 
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3(df_temp, product_name)
df_test.head(10)
# Out:
# Produits similaires au produit : Apple juice cocktail from concentrate
# CPU times: user 10.2 s, sys: 34.9 ms, total: 10.2 s
# Wall time: 10.2 s
#                                              product_name  \
# 73879                Clover valley, juice cocktail, apple
# 205647                 Apple Juice Drink From Concentrate
# 308674                       Bogopa, Apple Juice Cocktail
# 210870  Apple juice cocktail flavored with other natur...
# 162362                            Dreamworks, Fruit Punch
# 153943             Mr. Pure, Juice Drink, Apple Cranberry
# 250398  Cranberry apple flavored juice cocktail from c...
# 2868                       Cranberry Apple Juice Cocktail
# 320108                           Goliath, Nectar Tropical
# 52471   Cranberry apple juice cocktail from concentrat...
#
#                                         liste_ingredients  similarity1  \
# 73879   [filtered-water, water, high-fructose-corn-syr...     0.964740
# 205647  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 308674  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 210870  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 162362  [filtered-water, water, high-fructose-corn-syr...     0.987817
# 153943  [water, high-fructose-corn-syrup, added-sugar,...     0.963618
# 250398  [filtered-water, water, high-fructose-corn-syr...     0.949193
# 2868    [filtered-water, water, high-fructose-corn-syr...     0.949193
# 320108  [water, high-fructose-corn-syrup, added-sugar,...     0.968173
# 52471   [filtered-water, water, high-fructose-corn-syr...     0.965086
#
#         similarity2  mean_similarity
# 73879      1.000000         0.982370
# 205647     1.000000         0.976196
# 308674     1.000000         0.976196
# 210870     0.996696         0.974544
# 162362     0.952982         0.970400
# 153943     0.969001         0.966309
# 250398     0.980084         0.964639
# 2868       0.978741         0.963967
# 320108     0.956363         0.962268
# 52471      0.947506         0.956296

# %%
# %%time 
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(10)
# Out:
# Produits similaires au produit : Apple juice cocktail from concentrate
# CPU times: user 1.61 s, sys: 673 ms, total: 2.28 s
# Wall time: 10.2 s
#                                              product_name  \
# 73879                Clover valley, juice cocktail, apple
# 205647                 Apple Juice Drink From Concentrate
# 308674                       Bogopa, Apple Juice Cocktail
# 210870  Apple juice cocktail flavored with other natur...
# 162362                            Dreamworks, Fruit Punch
# 153943             Mr. Pure, Juice Drink, Apple Cranberry
# 250398  Cranberry apple flavored juice cocktail from c...
# 2868                       Cranberry Apple Juice Cocktail
# 320108                           Goliath, Nectar Tropical
# 52471   Cranberry apple juice cocktail from concentrat...
#
#                                         liste_ingredients  similarity1  \
# 73879   [filtered-water, water, high-fructose-corn-syr...     0.964740
# 205647  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 308674  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 210870  [water, high-fructose-corn-syrup, added-sugar,...     0.952392
# 162362  [filtered-water, water, high-fructose-corn-syr...     0.987817
# 153943  [water, high-fructose-corn-syrup, added-sugar,...     0.963618
# 250398  [filtered-water, water, high-fructose-corn-syr...     0.949193
# 2868    [filtered-water, water, high-fructose-corn-syr...     0.949193
# 320108  [water, high-fructose-corn-syrup, added-sugar,...     0.968173
# 52471   [filtered-water, water, high-fructose-corn-syr...     0.965086
#
#         similarity2  mean_similarity
# 73879      1.000000         0.982370
# 205647     1.000000         0.976196
# 308674     1.000000         0.976196
# 210870     0.996696         0.974544
# 162362     0.952982         0.970400
# 153943     0.969001         0.966309
# 250398     0.980084         0.964639
# 2868       0.978741         0.963967
# 320108     0.956363         0.962268
# 52471      0.947506         0.956296

# %% [markdown]
# La méthode V3 + multiprocessing est clairement la plus rapide, même sur un plus petit dataframe

# %% [markdown]
# ## Autres exemples de produits

# %% [markdown]
# Exemple de résultats sur 50 000 produits aléatoires pour réduire le temps d'exécution

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Nonfat greek yogurt
#                                              product_name  \
# 239073                  Greek strained yogurt with cherry
# 239070          Fage, total greek strained yogurt, cherry
# 239096                      Classic greek strained yogurt
# 239056                       Nonfat greek strained yogurt
# 89176   Premium blended black cherry authentic greek l...
# 239053                              Greek strained yogurt
# 486014                 Yaourt brassé sur lit de myrtilles
# 5327                       2% milkfat lowfat greek yogurt
# 689726       Greek Nonfat Yogurt With Fruit On The Bottom
# 239052                              Greek Strained Yogurt
# 291796                          Harmless harvest stawbery
# 59270                                            Smoothie
# 239092                       Greek nonfat strained yogurt
# 269640         Strawberry greek nonfat yogurt, strawberry
# 195554                             Greek yogurt blueberry
#
#                                         liste_ingredients  similarity1  \
# 239073  [cane-sugar, added-sugar, disaccharide, sugar,...     0.993806
# 239070  [cane-sugar, added-sugar, disaccharide, sugar,...     0.993806
# 239096  [cane-sugar, added-sugar, disaccharide, sugar,...     0.991402
# 239056  [cane-sugar, added-sugar, disaccharide, sugar,...     0.952307
# 89176   [cherry, fruit, cane-sugar, added-sugar, disac...     0.972279
# 239053  [cane-sugar, added-sugar, disaccharide, sugar,...     0.951567
# 486014  [blueberry, fruit, berries, water, cane-sugar,...     0.952265
# 5327    [sugar, added-sugar, disaccharide, corn-starch...     0.956619
# 689726  [sugar, added-sugar, disaccharide, orange, fru...     0.962068
# 239052  [cane-sugar, added-sugar, disaccharide, sugar,...     0.951567
# 291796  [cane-sugar, added-sugar, disaccharide, sugar,...     0.943401
# 59270   [cane-sugar, added-sugar, disaccharide, sugar,...     0.967467
# 239092  [cane-sugar, added-sugar, disaccharide, sugar,...     0.970727
# 269640  [streptococcus-thermophilus, ferment, microbia...     0.939460
# 195554  [sugar, added-sugar, disaccharide, blueberry, ...     0.933645
#
#         similarity2  mean_similarity
# 239073     0.994424         0.994115
# 239070     0.971998         0.982902
# 239096     0.967126         0.979264
# 239056     0.993893         0.973100
# 89176      0.970780         0.971529
# 239053     0.984592         0.968080
# 486014     0.981168         0.966717
# 5327       0.969788         0.963204
# 689726     0.956451         0.959259
# 239052     0.961618         0.956593
# 291796     0.963125         0.953263
# 59270      0.937780         0.952623
# 239092     0.932321         0.951524
# 269640     0.963493         0.951476
# 195554     0.968633         0.951139

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Chocolate sandwich cookies
#                                              product_name  \
# 105714                          Oreo cookies 12x10.700 oz
# 105797                   Oreo cookies hot cocoa 1x10.7 oz
# 106027                   Chocolate creme sandwich cookies
# 105764                           Oreo cookies 1x20.000 oz
# 62369           Original chocolate chip cookies, original
# 20085   Original chocolate chip cookies, original choc...
# 74687                              Chocolate Chip Cookies
# 93864                          Chocolate Sandwich Cookies
# 118070                         Chocolate Sandwich Cookies
# 133970          Original chocolate sandwich cookie cremes
# 106086                            Chocolage confetti cake
# 136193                        Crispy Wheat Snack Crackers
# 30353                        Wheat classic snack crackers
# 105463                   Nabisco oreo cookies 1x13.200 oz
# 105982                 Oreo cookies cherry cola 1x10.7 oz
#
#                                         liste_ingredients  similarity1  \
# 105714  [sugar, added-sugar, disaccharide, flour, palm...     0.991382
# 105797  [sugar, added-sugar, disaccharide, flour, palm...     0.991382
# 106027  [sugar, added-sugar, disaccharide, flour, palm...     0.990543
# 105764  [sugar, added-sugar, disaccharide, flour, palm...     0.990543
# 62369   [flour, sugar, added-sugar, disaccharide, palm...     0.989450
# 20085   [flour, sugar, added-sugar, disaccharide, palm...     0.989450
# 74687   [wheat-flour, cereal, flour, wheat, cereal-flo...     0.968883
# 93864   [sugar, added-sugar, disaccharide, flour, vege...     0.991406
# 118070  [sugar, added-sugar, disaccharide, flour, palm...     0.991406
# 133970  [flour, sugar, added-sugar, disaccharide, palm...     0.991406
# 106086  [sugar, added-sugar, disaccharide, flour, palm...     0.991382
# 136193  [flour, whole-wheat-flour, cereal, wheat, cere...     0.971420
# 30353   [flour, whole-wheat-flour, cereal, wheat, cere...     0.971420
# 105463  [sugar, added-sugar, disaccharide, flour, palm...     0.991382
# 105982  [sugar, added-sugar, disaccharide, flour, whea...     0.990453
#
#         similarity2  mean_similarity
# 105714     0.978811         0.985096
# 105797     0.978811         0.985096
# 106027     0.978318         0.984430
# 105764     0.971891         0.981217
# 62369      0.970196         0.979823
# 20085      0.970196         0.979823
# 74687      0.990347         0.979615
# 93864      0.967362         0.979384
# 118070     0.966565         0.978985
# 133970     0.966565         0.978985
# 106086     0.963738         0.977560
# 136193     0.983107         0.977263
# 30353      0.983107         0.977263
# 105463     0.962879         0.977131
# 105982     0.963538         0.976995

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Creamy peanut butter
#                                  product_name  \
# 112128                  Skippy, peanut butter
# 271659         Crunchy peanut butter, crunchy
# 252970                          Peanut butter
# 220845                          Peanut butter
# 110037           Creamy peanut butter, creamy
# 109736                                Crunchy
# 8001                  Roundy's, peanut butter
# 605693                                 skippy
# 10566                           Peanut butter
# 53010                           Peanut butter
# 134417                  Crunchy peanut butter
# 62691            Creamy peanut butter, creamy
# 200672                  Crunchy Peanut Butter
# 218000                 Peanut butter, crunchy
# 52911   Family gourmet, peanut butter, creamy
#
#                                         liste_ingredients  similarity1  \
# 112128  [roasted-peanuts, nut, peanut, sugar, added-su...     1.000000
# 271659  [roasted-peanuts, nut, peanut, sugar, added-su...     1.000000
# 252970  [roasted-peanuts, nut, peanut, sugar, added-su...     1.000000
# 220845  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 110037  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 109736  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 8001    [peanut, nut, sugar, added-sugar, disaccharide...     0.988989
# 605693  [peanut, nut, peanut-oil, oil-and-fat, vegetab...     0.996382
# 10566   [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 53010   [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 134417  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 62691   [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 200672  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 218000  [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
# 52911   [peanut, nut, sugar, added-sugar, disaccharide...     0.996382
#
#         similarity2  mean_similarity
# 112128     1.000000         1.000000
# 271659     1.000000         1.000000
# 252970     1.000000         1.000000
# 220845     1.000000         0.998191
# 110037     1.000000         0.998191
# 109736     1.000000         0.998191
# 8001       1.000000         0.994495
# 605693     0.992438         0.994410
# 10566      0.983148         0.989765
# 53010      0.983148         0.989765
# 134417     0.983148         0.989765
# 62691      0.983148         0.989765
# 200672     0.983148         0.989765
# 218000     0.983148         0.989765
# 52911      0.983148         0.989765

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Haselnusskerne
#                                              product_name  \
# 678199                                 Noisettes Grillées
# 384237  Noisettes torréfiées en poudre issues de l'agr...
# 454053                        Noisettes grillees sans sel
# 70313               Seitenbacher, low carb food hazelnuts
# 390242                                Noisettes en poudre
# 519588                            Haselnusskerne gemahlen
# 376560                        Noisette complète en poudre
# 443122                                  Purée de noisette
# 487507                             Noisettes décortiquées
# 643867          Damiano Roasted Hazelnut Butter - Organic
# 422999                                Noisettes en Poudre
# 364988                                Noisettes en poudre
# 664853              Avellana torrada en llenya (clofolla)
# 376603                                Noisettes en poudre
# 415769                             Purée noisette toastée
#
#                 liste_ingredients  similarity1  similarity2  mean_similarity
# 678199  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 384237  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 454053  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 70313   [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 390242  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 519588  [nut, tree-nut, hazelnut]          1.0          1.0              1.0
# 376560  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 443122  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 487507  [nut, tree-nut, hazelnut]          1.0          1.0              1.0
# 643867  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 422999  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 364988  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 664853  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 376603  [hazelnut, nut, tree-nut]          1.0          1.0              1.0
# 415769  [hazelnut, nut, tree-nut]          1.0          1.0              1.0

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Restaurant style white corn tortillas chips
#                                              product_name  \
# 301741                                     Tortilla Chips
# 653949              Gallette di Mais Integrale Biologiche
# 44849   Fritos Lightly Salted Corn Chips 9.75 Ounce Pl...
# 553853                           Maiswaffeln mit Meersalz
# 516816                               Maiswaffeln Meersalz
# 652360                             Gallette Mais e Quinoa
# 49397                               Golden fluff, popcorn
# 85419   Schnucks, authentic restaurant style tortilla ...
# 674950                             Maiz gigante sabor BBQ
# 466426                                      Pop corn salé
# 292708  Popcorn, Indiana, Fit Popcorn Chips, Himalayan...
# 548221                              Tortillia Chips Natur
# 530976                                             Nachos
# 563400                             Lightly Salted Doritos
# 180335  Snyder's of hanover, restaurant style tortilla...
#
#                                         liste_ingredients  similarity1  \
# 301741  [corn, cereal, vegetable-oil, oil-and-fat, veg...     1.000000
# 653949  [corn, cereal, corn-oil, oil-and-fat, vegetabl...     0.938672
# 44849   [corn, cereal, corn-oil, oil-and-fat, vegetabl...     0.910829
# 553853  [corn, cereal, corn-oil, oil-and-fat, vegetabl...     0.938672
# 516816  [corn, cereal, sea-salt, salt, corn-oil, oil-a...     0.938672
# 652360  [corn, cereal, corn-oil, oil-and-fat, vegetabl...     0.938672
# 49397   [vegetable-oil, oil-and-fat, vegetable-oil-and...     0.972848
# 85419   [cereal, corn, vegetable-oil, oil-and-fat, veg...     0.887696
# 674950  [corn, cereal, vegetable-oil, oil-and-fat, veg...     0.887696
# 466426  [corn, cereal, sunflower-oil, oil-and-fat, veg...     0.887886
# 292708  [corn, cereal, sunflower-oil, oil-and-fat, veg...     0.887886
# 548221  [cereal, corn, sunflower-oil, oil-and-fat, veg...     0.887886
# 530976  [cereal, corn, sunflower-oil, oil-and-fat, veg...     0.887886
# 563400  [corn, cereal, sunflower-oil, oil-and-fat, veg...     0.887886
# 180335  [vegetable-oil, oil-and-fat, vegetable-oil-and...     0.896907
#
#         similarity2  mean_similarity
# 301741     0.962887         0.981444
# 653949     1.000000         0.969336
# 44849      1.000000         0.955415
# 553853     0.971154         0.954913
# 516816     0.971154         0.954913
# 652360     0.971154         0.954913
# 49397      0.926619         0.949734
# 85419      1.000000         0.943848
# 674950     1.000000         0.943848
# 466426     0.997269         0.942578
# 292708     0.997269         0.942578
# 548221     0.997269         0.942578
# 530976     0.997269         0.942578
# 563400     0.989666         0.938776
# 180335     0.978064         0.937485

# %%
df_temp = df.sample(50000)
product_name = df_temp["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name)
df_test.head(15)
# Out:
# Produits similaires au produit : Nature's rancher, ground organic chicken
#                                         product_name  \
# 321164                                Ground chicken
# 102290                85% lean 15% fat ground turkey
# 69984                                  Ground Turkey
# 36586                                  Ground turkey
# 102599                       Jennie-o, ground turkey
# 102484                            Lean ground turkey
# 40517      Oven roasted chicken breast, oven roasted
# 225503   Pine Manor Farms, Extra Lean Ground Chicken
# 217391  Organic boneless and skinless chicken breast
# 196494     No salt added chicken bone broth, chicken
# 327560             Emincé De Dinde Kebab Cuit ~1kgx4
# 317425                         Organic ground turkey
# 329957                                        Turkey
# 215009                        93% Lean Ground Turkey
# 215203                                 Dinde de Fête
#
#                                         liste_ingredients  similarity1  \
# 321164                           [chicken, poultry, e392]     1.000000
# 102290                            [turkey, poultry, e392]     0.998805
# 69984                             [turkey, poultry, e392]     0.998805
# 36586                             [turkey, poultry, e392]     0.998805
# 102599                            [turkey, poultry, e392]     0.998805
# 102484                            [turkey, poultry, e392]     0.998805
# 40517   [chicken-breast, poultry, chicken, chicken-mea...     1.000000
# 225503   [chicken-breast, poultry, chicken, chicken-meat]     0.796170
# 217391   [chicken-breast, poultry, chicken, chicken-meat]     0.796170
# 196494  [chicken-broth, poultry, broth, chicken, poult...     0.891577
# 327560                                  [turkey, poultry]     0.806598
# 317425                                  [turkey, poultry]     0.806598
# 329957                                  [turkey, poultry]     0.806598
# 215009                                  [turkey, poultry]     0.806598
# 215203                                  [turkey, poultry]     0.806598
#
#         similarity2  mean_similarity
# 321164     1.000000         1.000000
# 102290     0.983604         0.991204
# 69984      0.983604         0.991204
# 36586      0.983604         0.991204
# 102599     0.983604         0.991204
# 102484     0.983604         0.991204
# 40517      0.807623         0.903812
# 225503     0.986675         0.891422
# 217391     0.986675         0.891422
# 196494     0.890993         0.891285
# 327560     0.975406         0.891002
# 317425     0.975406         0.891002
# 329957     0.975406         0.891002
# 215009     0.975406         0.891002
# 215203     0.975406         0.891002

# %% [markdown]
# Exemples de résultats sur tout le dataframe :

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Lowes foods, macaroni & cheese
#                                    product_name  \
# 11169                  Macaroni & cheese dinner
# 259516   Lowes foods, macaroni spirals & cheese
# 10993       Dinosaurs macaroni & cheese dinner'
# 11172           Spiral dinner macaroni & cheese
# 10580                  Macaroni & cheese dinner
# 247591               Macaroni and cheese dinner
# 246448               Macaroni and cheese dinner
# 195986  Market pantry, macaroni & cheese dinner
# 6457                   Macaroni & cheese dinner
# 5921                             Mac and cheese
# 5924                  Kroger, macaroni & cheese
# 315181                      Macaroni and cheese
#
#                                         liste_ingredients  similarity1  \
# 11169   [wheat-flour, cereal, flour, wheat, cereal-flo...     1.000000
# 259516  [wheat-flour, cereal, flour, wheat, cereal-flo...     1.000000
# 10993   [wheat-flour, cereal, flour, wheat, cereal-flo...     1.000000
# 11172   [wheat-flour, cereal, flour, wheat, cereal-flo...     1.000000
# 10580   [wheat-flour, cereal, flour, wheat, cereal-flo...     1.000000
# 247591  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.998796
# 246448  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.998796
# 195986  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.998796
# 6457    [wheat-flour, cereal, flour, wheat, cereal-flo...     0.998796
# 5921    [wheat-flour, cereal, flour, wheat, cereal-flo...     0.998796
# 5924    [e375, reduced-iron, minerals, iron, thiamin-m...     0.989126
# 315181  [dairy, flour, cheddar, cheese, salt, modified...     0.984869
#
#         similarity2  mean_similarity
# 11169      0.995470         0.997735
# 259516     0.995470         0.997735
# 10993      0.995470         0.997735
# 11172      0.995470         0.997735
# 10580      0.995470         0.997735
# 247591     0.995323         0.997060
# 246448     0.995323         0.997060
# 195986     0.995323         0.997060
# 6457       0.994027         0.996411
# 5921       0.994027         0.996411
# 5924       0.993840         0.991483
# 315181     0.979550         0.982209

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Lemppari
#                                            product_name  \
# 596836                            Flatbread Street Food
# 346115                        Stenovns Ciabatta Stykker
# 596688                                   Reilu täysjyvä
# 322985                                     pain spécial
# 450540                                     Pain spécial
# 596689                                            Reilu
# 408430                          Boule Tranchée Complète
# 391117                Demi baguettes précuite complètes
# 653834                           Mollete estilo andaluz
# 596817                                     Vehnä paahto
# 482122  Le petit paillasse du larzac la pièce de 270 gr
# 482117                         Galzin Le pavé du Larzac
#
#                                         liste_ingredients  similarity1  \
# 596836  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.976443
# 346115  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.924376
# 596688  [whole-wheat-flour, cereal, flour, wheat, cere...     0.943876
# 322985  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.951694
# 450540  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.951694
# 596689  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.921169
# 408430  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.948029
# 391117  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.943125
# 653834  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.930122
# 596817  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.921169
# 482122  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.933377
# 482117  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.933377
#
#         similarity2  mean_similarity
# 596836     0.961098         0.968771
# 346115     0.998435         0.961405
# 596688     0.976220         0.960048
# 322985     0.965241         0.958467
# 450540     0.965241         0.958467
# 596689     0.995370         0.958269
# 408430     0.964870         0.956449
# 391117     0.958853         0.950989
# 653834     0.970040         0.950081
# 596817     0.978860         0.950014
# 482122     0.962435         0.947906
# 482117     0.962435         0.947906

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Tomato Ketchup
#                                  product_name  \
# 675646                    Ketchup à la tomate
# 675766                            Hot Ketchup
# 478925                    Ketchup à la tomate
# 478937                         Tomato ketchup
# 220     Tomato Ketchup Heinz Ouverture En Bas
# 675564                    Ketchup à la tomate
# 675701                   Heinz Tomato Ketchup
# 560602             Emblématique ketchup HEINZ
# 647777      Tomato Ketchup (offre Découverte)
# 675645                         Tomato ketchup
# 563248        Tomato Ketchup (20% extra free)
# 675629                         Tomato ketchup
#
#                                         liste_ingredients  similarity1  \
# 675646  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 675766  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 478925  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 478937  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 220     [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 675564  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 675701  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 560602  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 647777  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 675645  [tomato, vegetable, vinegar, sugar, added-suga...          1.0
# 563248  [tomato, vegetable, alcohol-vinegar, vinegar, ...          1.0
# 675629  [tomato, vegetable, alcohol-vinegar, vinegar, ...          1.0
#
#         similarity2  mean_similarity
# 675646       1.0000          1.00000
# 675766       1.0000          1.00000
# 478925       1.0000          1.00000
# 478937       1.0000          1.00000
# 220          1.0000          1.00000
# 675564       1.0000          1.00000
# 675701       1.0000          1.00000
# 560602       1.0000          1.00000
# 647777       1.0000          1.00000
# 675645       1.0000          1.00000
# 563248       0.9983          0.99915
# 675629       0.9983          0.99915

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Mor Braz Bio Blonde (5%)
#                                  product_name  \
# 578098            Bière belge Victoria blonde
# 489739                       Briarde - Ambrée
# 501947                             On the top
# 568604                          Hoppel Hammer
# 539490                                Urstrom
# 500916                   L'Eurélienne Blanche
# 498236                      Lager des étoiles
# 498237                        Gens de la Lune
# 597438  Terapia Platin - Bere albă nefiltrată
# 485111                        Gallia Brut IPA
# 500913                    L'Eurélienne Blonde
# 498311                                  Hegoa
#
#                                        liste_ingredients  similarity1  \
# 578098               [water, hops, plant, cereal, yeast]          1.0
# 489739               [cereal, water, hops, plant, yeast]          1.0
# 501947  [water, malt, cereal, wheat, hops, plant, yeast]          1.0
# 568604  [malt, cereal, wheat, hops, plant, water, yeast]          1.0
# 539490         [water, malt, cereal, yeast, hops, plant]          1.0
# 500916         [water, malt, cereal, hops, plant, yeast]          1.0
# 498236         [water, malt, cereal, hops, plant, yeast]          1.0
# 498237         [water, malt, cereal, hops, plant, yeast]          1.0
# 597438         [water, hops, plant, malt, cereal, yeast]          1.0
# 485111         [water, malt, cereal, hops, plant, yeast]          1.0
# 500913         [water, malt, cereal, hops, plant, yeast]          1.0
# 498311         [water, malt, cereal, hops, plant, yeast]          1.0
#
#         similarity2  mean_similarity
# 578098     1.000000         1.000000
# 489739     1.000000         1.000000
# 501947     0.969785         0.984892
# 568604     0.969785         0.984892
# 539490     0.967949         0.983974
# 500916     0.967949         0.983974
# 498236     0.967949         0.983974
# 498237     0.967949         0.983974
# 597438     0.967949         0.983974
# 485111     0.967949         0.983974
# 500913     0.967949         0.983974
# 498311     0.967949         0.983974

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Légumes vapeur assaisonnés - Trio de haricots et poivrons
#                                              product_name  \
# 472770  Légumes vapeur assaisonnés - Sélection de 4 lé...
# 394991  Légumes Vapeur haricots beurre et plat et poiv...
# 457723                             Légumes Méditerranéens
# 394992  Légumes Vapeur petits pois, haricots verts et ...
# 348052      Mélange de légumes et pommes de terre surgelé
# 404714                         Purée de Céleris - Surgelé
# 374229                       Les légumes à la Printanière
# 394990  Légumes Vapeur chou fleur, chou romanesco, bro...
# 363015                        Poêlée ratatouille cuisinée
# 388179                             Petits Mélanges vapeur
# 568783                                                nan
# 307091                                   Fine green beans
#
#                                         liste_ingredients  similarity1  \
# 472770  [garden-peas, legume, pea, green-peas, green-b...     0.977088
# 394991  [legume, green-bean, vegetable, bell-pepper, r...     0.924962
# 457723  [water, extra-virgin-olive-oil, oil-and-fat, v...     0.915054
# 394992  [green-bean, legume, pea, water, extra-virgin-...     0.914918
# 348052  [vegetable, root-vegetable, carrot, legume, gr...     0.939927
# 404714  [celery, vegetable, water, butterfat, dairy, o...     0.895610
# 374229  [vegetable, root-vegetable, onion, butterfat, ...     0.927186
# 394990  [vegetable, cauliflower, root-vegetable, carro...     0.901705
# 363015  [vegetable, water, tomato-concentrate, tomato,...     0.901893
# 388179  [vegetable, broccoli, cauliflower, water, extr...     0.894259
# 568783  [tomato, vegetable, water, olive-oil, oil-and-...     0.919637
# 307091  [green-peas, legume, pea, red-bell-pepper, veg...     0.937566
#
#         similarity2  mean_similarity
# 472770     0.983856         0.980472
# 394991     1.000000         0.962481
# 457723     1.000000         0.957527
# 394992     0.998499         0.956708
# 348052     0.955844         0.947885
# 404714     1.000000         0.947805
# 374229     0.966873         0.947030
# 394990     0.986765         0.944235
# 363015     0.981897         0.941895
# 388179     0.987462         0.940861
# 568783     0.955271         0.937454
# 307091     0.936276         0.936921

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Chicken Breast Nuggets With Rib Meat
#                                              product_name  \
# 288073                             Chicken Breast Patties
# 288074  Breaded full cooked chicken breast tenders wit...
# 288072  Breaded Fully Cooked Chicken Breast Rings With...
# 315681  Fully cooked portioned chicken fillet white me...
# 210670                             Corn veggie tots, corn
# 210655               Cauliflower veggie tots, cauliflower
# 210656                     Broccoli veggie tots, broccoli
# 210671  Sweet potato & cauliflower veggie tots, sweet ...
# 158454                   Chicken Fried Steak Breading Mix
# 316071                                      Chicken Rings
# 6413                Chicken & cheese cornbread sandwiches
# 63453                          Breaded mushrooms, breaded
#
#                                         liste_ingredients  similarity1  \
# 288073  [water, modified-starch, starch, salt, sugar, ...     0.992367
# 288074  [water, modified-starch, starch, salt, sodium,...     0.981804
# 288072  [water, modified-starch, starch, salt, sodium,...     0.981804
# 315681  [chicken-breast, poultry, chicken, chicken-mea...     0.967513
# 210670  [soya-oil, oil-and-fat, vegetable-oil-and-fat,...     0.967539
# 210655  [cauliflower, vegetable, soya-oil, oil-and-fat...     0.967539
# 210656  [broccoli, vegetable, soya-oil, oil-and-fat, v...     0.967539
# 210671  [sweet-potato, vegetable, root-vegetable, caul...     0.969926
# 158454  [wheat-flour, cereal, flour, wheat, cereal-flo...     0.921436
# 316071  [water, coating, reduced-iron, minerals, iron,...     0.967613
# 6413    [barley-malt-flour, cereal, flour, cereal-flou...     0.981209
# 63453   [mushroom, water, wheat-flour, cereal, flour, ...     0.966107
#
#         similarity2  mean_similarity
# 288073     0.999187         0.995777
# 288074     0.999140         0.990472
# 288072     0.999140         0.990472
# 315681     0.957202         0.962357
# 210670     0.951326         0.959432
# 210655     0.949927         0.958733
# 210656     0.948916         0.958227
# 210671     0.946115         0.958021
# 158454     0.986562         0.953999
# 316071     0.937969         0.952791
# 6413       0.922682         0.951945
# 63453      0.936523         0.951315

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Procacci Brothers, Italian Chestnuts
#                                            product_name liste_ingredients  \
# 379585                              Châtaignes entières   [nut, tree-nut]
# 354744          Marrons Entiers Sous Vide, à L'étouffée   [nut, tree-nut]
# 381317                                         Marronen   [nut, tree-nut]
# 583067                                   Erdmandel Mehl   [nut, tree-nut]
# 230027         Elizabeth's naturals, raw macadamia nuts   [nut, tree-nut]
# 381316                      Ponthier : Gekochte Maronen   [nut, tree-nut]
# 381315                                    Marrons cuits   [nut, tree-nut]
# 502610                          Châtaignes entières bio   [nut, tree-nut]
# 155675                 Mauna loa, dry roasted macadamia   [nut, tree-nut]
# 325224  Châtaigne Bouche Rouge G2 CAT 2 BIO France ~5kg   [nut, tree-nut]
# 507036                                 Mandeln gemahlen   [nut, tree-nut]
# 502609                          Châtaignes entières bio   [nut, tree-nut]
#
#         similarity1  similarity2  mean_similarity
# 379585          1.0          1.0              1.0
# 354744          1.0          1.0              1.0
# 381317          1.0          1.0              1.0
# 583067          1.0          1.0              1.0
# 230027          1.0          1.0              1.0
# 381316          1.0          1.0              1.0
# 381315          1.0          1.0              1.0
# 502610          1.0          1.0              1.0
# 155675          1.0          1.0              1.0
# 325224          1.0          1.0              1.0
# 507036          1.0          1.0              1.0
# 502609          1.0          1.0              1.0

# %%
product_name = df["product_name"].sample().iloc[0]
print(f"Produits similaires au produit : {product_name}")
df_test = find_similar_products_max_pooling_both_waysV3_multiprocessing(df, product_name)
df_test.head(12)
# Out:
# Produits similaires au produit : Hot Cocoa With Natural & Artificial Flavors Of Peanut Butter Cup & Fugge
#                                              product_name  \
# 126839               Rich & Creamy Hot Cocoa Beverage Mix
# 299781  Duck Commander, Duck-Cups Cocoa Coffee, Uncle ...
# 80851                  Milk chocolate hot cocoa drink mix
# 32483                                 Hot Cocoa Drink Mix
# 84146   Milk chocolate flavor hot cocoa drink mix, mil...
# 34508   Milk chocolate hot cocoa drink mix, milk choco...
# 314864                                          Hot Cocoa
# 58564                       French vanilla cappuccino mix
# 132962  Mild coffee and hazelnut flavor cappuccino mix...
# 132961  Mild coffee and french vanilla flavor cappucci...
# 58563   Milk chocolate flavored hot cocoa mix, milk ch...
# 132965  Sweet salty caramel chocolate flavor hot cocoa...
#
#                                         liste_ingredients  similarity1  \
# 126839  [sugar, added-sugar, disaccharide, corn-syrup-...     1.000000
# 299781  [sugar, added-sugar, disaccharide, cocoa, salt...     0.994241
# 80851   [sugar, added-sugar, disaccharide, corn-syrup-...     0.994241
# 32483   [sugar, added-sugar, disaccharide, corn-syrup-...     0.994241
# 84146   [sugar, added-sugar, disaccharide, corn-syrup-...     0.994241
# 34508   [sugar, added-sugar, disaccharide, corn-syrup-...     0.994241
# 314864  [sugar, added-sugar, disaccharide, cocoa, skim...     0.994241
# 58564   [corn-syrup-solids, added-sugar, disaccharide,...     1.000000
# 132962  [corn-syrup-solids, added-sugar, disaccharide,...     1.000000
# 132961  [corn-syrup-solids, added-sugar, disaccharide,...     1.000000
# 58563   [corn-syrup-solids, added-sugar, disaccharide,...     1.000000
# 132965  [corn-syrup-solids, added-sugar, disaccharide,...     1.000000
#
#         similarity2  mean_similarity
# 126839     0.989084         0.994542
# 299781     0.984349         0.989295
# 80851      0.983445         0.988843
# 32483      0.983445         0.988843
# 84146      0.983445         0.988843
# 34508      0.983445         0.988843
# 314864     0.978067         0.986154
# 58564      0.972197         0.986098
# 132962     0.972197         0.986098
# 132961     0.972197         0.986098
# 58563      0.971087         0.985544
# 132965     0.970929         0.985465

# %% [markdown]
# #### Essai de calcul des similarités pour 100 produits avec un dataset de 10 000 produits

# %%
# %%time
df_temp = df.sample(10000)
products_similarities={}
for i in tqdm(range(100)): 
    product_name = df_temp["product_name"].sample().iloc[0]
    products_similarities[product_name] = find_similar_products_max_pooling_both_waysV3_multiprocessing(df_temp, product_name).set_index("product_name")["mean_similarity"].to_dict()
# Out:
# 100%|██████████| 100/100 [04:06<00:00,  2.46s/it]
# CPU times: user 32.4 s, sys: 31.9 s, total: 1min 4s
# Wall time: 4min 6s
